# %%
# !pip install selenium

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10
# jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\nisar\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
Location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
Location.send_keys('Bangalore')

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()

# %%
jobtitle=[]
joblocation=[]
companyname=[]
experiencerequired=[]

# %%
#scraping job title
title_tag=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    jobtitle.append(title)

#scraping job location
location_tag=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tag[0:10]:
    location=i.text
    joblocation.append(location)

#scraping company name
company_tag=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    companyname.append(company)
    
#scraping experiance
exp_tag=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in exp_tag[0:10]:
    exp=i.text
    experiencerequired.append(exp)

# %%
print(len(jobtitle),len(joblocation),len(companyname),len(experiencerequired))
# Out:
# 10 10 10 10

# %%
df=pd.DataFrame({'job_title':jobtitle,'job_location':joblocation,'company_name':companyname,'experience_required':experiencerequired})
df
# Out:
#                                            job_title  \
# 0                 Business Analyst/ Sr. Data Analyst
# 1                                    Sr Data Analyst
# 2  Business Analyst - Clinical data , Sales Comme...
# 3                                Senior Data Analyst
# 4                     Senior Data Management Analyst
# 5                Data Analyst (Only from Big4 firms)
# 6                             Manager - Data Analyst
# 7                                       Data Analyst
# 8                                       Data Analyst
# 9                     Lead Data Analyst(SQL, Python)
#
#                                   job_location               company_name  \
# 0     Hybrid - Bangalore/Bengaluru(Whitefield)       Zen Data Shastra Llp
# 1                          Bangalore/Bengaluru                   Skillety
# 2     Noida, Pune, Gurgaon/Gurugram, Bangalore                     Axtria
# 3  Bangalore/Bengaluru, Hyderabad/Secunderabad  Quince Corporate Services
# ...

# %% [markdown]
# Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You
# have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. First get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, Companies” field and enter “Bangalore” in “enter the
# location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\nisar\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
Location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
Location.send_keys('Bangalore')

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()

# %%
jobtitle_ds=[]
joblocation_ds=[]
companyname_ds=[]

# %%
#scraping job title
title_tag=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    jobtitle_ds.append(title)

#scraping job location
location_tag=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tag[0:10]:
    location=i.text
    joblocation_ds.append(location)

#scraping company name
company_tag=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    companyname_ds.append(company)

# %%
print(len(jobtitle),len(joblocation),len(companyname))
# Out:
# 10 10 10

# %%
df1=pd.DataFrame({'job_title':jobtitle_ds,'job_location':joblocation_ds,'company_name':companyname_ds})
df1
# Out:
#                                            job_title  \
# 0                                     Data Scientist
# 1                   Analystics & Modeling Specialist
# 2                                            Manager
# 3  Opportunity For BioStatistician - II/Sr/Princi...
# 4                                     Data Scientist
# 5                              Senior Data Scientist
# 6                                     Data Scientist
# 7       Data & Analytics Lead, Geo Analytics - GAMMA
# 8                 Weather and Climate Data Scientist
# 9                               Manager-Data Science
#
#                                         job_location             company_name
# 0  Hybrid - Bangalore/Bengaluru, Noida, Hyderabad...                Birlasoft
# 1  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...                Accenture
# 2  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...                      PwC
# ...

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below
#     You have to use the location and salary filter.
# You have to scrape data for “Data Scientist” designation for first 10 job results.
# You have to scrape the job-title, job-location, company name, experience required.
# The location filter to be used is “Delhi/NCR”. The salary filter to be used is “3-6” lakhs
# The task will be done as shown in the below steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill, Designations, and Companies” field.
# 3. Then click the search button.
# 4. Then apply the location filter and salary filter by checking the respective boxes
# 5. Then scrape the data for the first 10 jobs results you get.
# 6. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome(r"C:\Users\nisar\chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
designation=driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Scientist')

# %%
Location=driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
Location.send_keys('Banglore')

# %%
Search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
Search.click()

# %%
location_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[3]')
location_filter.click()

# %%
salary_filter = driver.find_element(By.XPATH,'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[6]/div[2]/div[2]/label/p/span[1]')
salary_filter.click()

# %%
jobtitle_F=[]
joblocation_F=[]
companyname_F=[]
experiencerequired_F=[]

# %%
#scraping job title
title_tag=driver.find_elements(By.XPATH,'//a[@class="title fw500 ellipsis"]')
for i in title_tag[0:10]:
    title=i.text
    jobtitle_F.append(title)

#scraping job location
location_tag=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi location"]')
for i in location_tag[0:10]:
    location=i.text
    joblocation_F.append(location)

#scraping company name
company_tag=driver.find_elements(By.XPATH,'//a[@class="subTitle ellipsis fleft"]')
for i in company_tag[0:10]:
    company=i.text
    companyname_F.append(company)
    
#scraping experiance
exp_tag=driver.find_elements(By.XPATH,'//li[@class="fleft grey-text br2 placeHolderLi experience"]//span')
for i in exp_tag[0:10]:
    exp=i.text
    experiencerequired_F.append(exp)

# %%
print(len(jobtitle_F),len(joblocation_F),len(companyname_F),len(experiencerequired_F))
# Out:
# 10 10 10 10

# %%
df2=pd.DataFrame({'job_title':jobtitle_F,'job_location':joblocation_F,'company_name':companyname_F, 'expre':experiencerequired_F})
df2
# Out:
#                                            job_title  \
# 0  Artificial Intelligence/Computer Vision Engine...
# 1          Data Activation Specialist - Adobe Target
# 2                  Data Scientist - Engine Algorithm
# 3  Opening For Jr. Data Scientist with Tatras Dat...
# 4                                     Data Scientist
# 5                                     Data Scientist
# 6  URGENT: Data Scientist | Gurugram | 5 Days Wor...
# 7  Data Scientist | Boutique AI and data consulti...
# 8                                     Data Scientist
# 9                              SE/SSE-Data Scientist
#
#                                         job_location  \
# 0  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 1  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 2  Delhi / NCR, Kolkata, Mumbai, Hyderabad/Secund...
# 3                                        Delhi / NCR
# 4  Dehradun, Hyderabad/Secunderabad, Gurgaon/Guru...
# 5                                   Gurgaon/Gurugram
# ...

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. ProductDescription
# 3. Price
# The attributes which you have to scrape is ticked marked in the below image.

# %%
driver=webdriver.Chrome(r"C:\Users\nisar\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sunglasses')

# %%
Search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
Search.click()

# %%
brand=[]
productdescription=[]
price=[]

# %%
#scraping brand-page1
brand_tag=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tag:
    bran=i.text
    brand.append(bran)

#scraping product description- page 1
productdescription_tag=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in productdescription_tag:
    pd=i.text
    productdescription.append(pd)

#scraping price-page 1
price_tag=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tag:
    pri=i.text
    price.append(pri)

# %%
print(len(brand),len(productdescription),len(price))
# Out:
# 40 40 40

# %%
#moving to next page(2)
next_button=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next_button.click()

# %%
brand2=[]
productdescription2=[]
price2=[]


#scraping brand-page2
brand_tag2=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tag2:
    bran=i.text
    brand2.append(bran)

#scraping product description- page 2
productdescription_tag2=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in productdescription_tag2:
    pd=i.text
    productdescription2.append(pd)

#scraping price-page 2
price_tag2=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tag2:
    pri=i.text
    price2.append(pri)

# %%
print(len(brand2),len(productdescription2),len(price2))
# Out:
# 40 40 40

# %%
#moving to next page(3)
next_button=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]")
next_button.click()

# %%
brand3=[]
productdescription3=[]
price3=[]


#scraping brand-page2
brand_tag3=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand_tag3:
    bran=i.text
    brand3.append(bran)

#scraping product description- page 2
productdescription_tag3=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in productdescription_tag3:
    pd=i.text
    productdescription3.append(pd)

#scraping price-page 2
price_tag3=driver.find_elements(By.XPATH,'//a[@class="_3bPFwb"]')
for i in price_tag3:
    pri=i.text
    price3.append(pri)

# %%
print(len(brand3),len(productdescription3),len(price3))
# Out:
# 40 40 40

# %%
#Combining data of all 3 pages
Brand_Name=brand+brand2+brand3
Product_Description=productdescription+productdescription2+productdescription3
Price_rs=price+price2+price3

# %%
print(len(Brand_Name),len(Product_Description),len(Price_rs))
# Out:
# 120 120 120

# %%
flipkart = pd.DataFrame({'Brand Name':Brand_Name[0:100], "Decription":Product_Description[0:100], 'Price':Price_rs[0:100]})
flipkart
# Out:
#         Brand Name                                         Decription  \
# 0   ROZZETTA CRAFT  UV Protection, Gradient Round Sunglasses (Free...
# 1    VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 2         Fastrack   UV Protection Rectangular Sunglasses (Free Size)
# 3       LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 4        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# ..             ...                                                ...
# 95   VINCENT CHASE  by Lenskart Polarized, UV Protection Rectangul...
# 96          AISLIN  UV Protection, Gradient Over-sized, Retro Squa...
# 97   VINCENT CHASE     Polarized, UV Protection Round Sunglasses (51)
# 98       Rich Club                  Gradient Wayfarer Sunglasses (52)
# 99   VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
#
#                                Price
# 0   ₹399₹1,99980% off\nFree delivery
# 1   ₹806₹1,99959% off\nFree delivery
# ...

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb/productreviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market
# place=FLIPKART
#
# As shown in the above page you have to scrape the tick marked attributes. These are:
# 1. Rating
# 2. Review summary
# 3. Full review
# 4. You have to scrape this data for first 100 reviews.

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market')

# %%
star = []
comm = []
bri = []
for page in range(0,10):
    for i in driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]'):
        star.append(i.text)
        
    for i in driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]'):
        comm.append(i.text)
    
    for i in driver.find_elements(By.XPATH,'//div[@class = "t-ZTKy"]'):
        bri.append(i.text)

# %%
phone = pd.DataFrame({'Star':star, 'Comments':comm, 'Brief':bri})
phone
# Out:
#    Star             Comments  \
# 0     5       Simply awesome
# 1     5     Perfect product!
# 2     5  Best in the market!
# 3     4      Value-for-money
# 4     5   Highly recommended
# ..  ...                  ...
# 95    5    Worth every penny
# 96    5   Highly recommended
# 97    5     Perfect product!
# 98    5        Great product
# 99    4          Pretty good
#
#                                                 Brief
# 0   Really satisfied with the Product I received.....
# 1   Amazing phone with great cameras and better ba...
# 2   Great iPhone very snappy experience as apple k...
# 3   I'm Really happy with the product\nDelivery wa...
# 4   It's my first time to use iOS phone and I am l...
# ..                                                ...
# 95  Previously I was using one plus 3t it was a gr...
# 96  What a camera .....just awesome ..you can feel...
# 97  Value for money\n5 star rating\nExcellent came...
# 98  Amazing Powerful and Durable Gadget.\n\nI’m am...
# ...

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the
# search field.
# You have to scrape 4 attributes of each sneaker:
# 1. Brand
# 2. ProductDescription
# 3. Price
# As shown in the below image, you have to scrape the tick marked attributes.

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.flipkart.com/')

# %%
product=driver.find_element(By.CLASS_NAME,"_3704LK")
product.send_keys('sneakers')

# %%
name=[]
des=[]
pir=[]
off = []
for page in range(0,3):
    for i in driver.find_elements(By.CLASS_NAME,'_2WkVRV'):
        name.append(i.text)
    
    for i in driver.find_elements(By.CLASS_NAME,'IRpwTa'):
        des.append(i.text)
        
    for i in driver.find_elements(By.XPATH,'//div[@class = "_30jeq3"]'):
        pir.append(i.text)
    
    for i in driver.find_elements(By.CLASS_NAME,'_3Ay6Sb'):
        off.append(i.text)

# %%
len(name),len(des),len(pir),len(off)
# Out:
# (120, 120, 120, 135)

# %%
Search=driver.find_element(By.CLASS_NAME,"L0Z3Pu")
Search.click()

# %%
sneaker = pd.DataFrame({'Brand':name[0:100], 'Product Description':des[0:100], 'Price':pir[0:100], 'Offer':off[0:100]})

# %%
sneaker
# Out:
#                   Brand                                Product Description  \
# 0                   SFR  FAST Trenddy Tainer Lace-ups Sporty Casuals Sn...
# 1   World Wear Footwear  Latest Exclusive Affordable Collection of Tren...
# 2                  aadi  Synthetic Leather |Lightweight|Comfort|Summer|...
# 3                BRUTON              Canvas shoes for Men Sneakers For Men
# 4                Shozie                                   Sneakers For Men
# ..                  ...                                                ...
# 95               Kraasa                                 Sneakers For Women
# 96     kainchee factory  Kainchee factory blue Sneakers Shoes for Mens ...
# 97             RapidBox                                   Sneakers For Men
# 98               Shozie  Breathable, Walking, Running, Casual,Gym Shoes...
# 99               Kraasa        Casuals, Canvas, Partywear Sneakers For Men
#
#    Price    Offer
# 0   ₹369  62% off
# 1   ₹399  80% off
# ...

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/
# Enter “Laptop” in the search field and then click the search icon.
# Then set CPU Type filter to “Intel Core i7” as shown in the below image

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.amazon.in/ ')

# %%
product=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
product.send_keys('Laptop')
product.submit()

# %%
filter = driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[6]/li[15]/span/a/span')
filter.click()

# %%
title=[]
rating=[]
price=[]

for i in driver.find_elements(By.XPATH,'//a[@class = "a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]'):
    title.append(i.text)

for i in driver.find_elements(By.XPATH,'//span[@class = "a-price-whole"]'):
    rating.append(i.text)

for i in driver.find_elements(By.XPATH,'//span[@class="a-size-base s-underline-text"]'):
    price.append(i.text)

# %%
len(title),len(rating),len(price)
# Out:
# (38, 38, 34)

# %%
laptop = pd.DataFrame({'Title': title[0:10], 'Rating': rating[0:10], 'Price' : price[0:10]})
laptop
# Out:
#                                                Title    Rating Price
# 0  Fujitsu UH-X 12th Gen Intel Evo Core i7 13.3 i...    99,990  (55)
# 1  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...    99,990   (9)
# 2  Acer Nitro 5 Gaming Laptop Intel core i7 11th ...    82,990  (93)
# 3  HP Victus Gaming Latest 12th Gen Intel Core i7...    85,990  (23)
# 4  HP Pavilion x360 11th Gen Intel Core i7 14 inc...    82,490  (56)
# 5  Lenovo IdeaPad Slim 5 12th Gen Intel Core i7 1...    82,990  (29)
# 6  Lenovo ThinkBook 15 Intel 11th Gen Core i7 15....    81,990  (42)
# 7  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...    24,925  (34)
# 8  ASUS Zenbook 14 OLED (2022), 14" (35.56 cms) 2...  1,02,000  (18)
# 9  (Renewed) HP ProBook 430 G3 6th Gen Intel Core...    22,999  (56)

# %% [markdown]
# Q8: Write a python program to scrape data for Top 1000 Quotes of All Time.
# The above task will be done in following steps:
# 1.First get the webpage https://www.azquotes.com/
# 2. Click on Top Quote
# 3. Than scrap a) Quote b) Author c) Type Of Quote

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.azquotes.com/')

# %%
Top_Quote = driver.find_element(By.XPATH,'/html/body')
Top_Quote.click()

# %%
quote=[]
Author=[]
type_of=[]

for page in range(0,10):
    for i in driver.find_elements(By.CLASS_NAME,'title'):
        quote.append(i.text)
    
    for i in driver.find_elements(By.CLASS_NAME,'author'):
        Author.append(i.text)
        
    for i in driver.find_elements(By.CLASS_NAME,'tags'):
        type_of.append(i.text)

# %%
len(quote),len(Author),len(type_of)
# Out:
# (1040, 1000, 1000)

# %%
TOP1000 = pd.DataFrame({'Quote': quote[0:1000], 'Author': Author[0:1000], 'type of quote' : type_of[0:1000]})
TOP1000
# Out:
#                                                  Quote                Author  \
# 0                                                             Michael Porter
# 1    The essence of strategy is choosing what not t...            Golda Meir
# 2    One cannot and must not try to erase the past ...    Theodore Roosevelt
# 3    Patriotism means to stand by the country. It d...        Nelson Mandela
# 4    Death is something inevitable. When a man has ...          Erma Bombeck
# ..                                                 ...                   ...
# 995  Trying to do the Lord's work in your own stren...    Hunter S. Thompson
# 996  Sports for me is when a guy walks off the cour...       Corrie Ten Boom
# 997  Expect the best. Prepare for the worst. Capita...            Dalai Lama
# 998  I became insane, with long intervals of horrib...         Mother Teresa
# 999        Failure is a detour, not a dead-end street.  Norman Vincent Peale
#
# ...

# %% [markdown]
# Q9: Write a python program to display list of respected former Prime Ministers of India(i.e. Name, Born-Dead,
# Term of office, Remarks) from https://www.jagranjosh.com/.
# This task will be done in following steps:
# 1. First get the webpage https://www.jagranjosh.com/
# 2. Then You have to click on the GK option
# 3. Then click on the List of all Prime Ministers of India
# 4. Then scrap the mentioned data and make the DataFrame

# %%
import selenium 
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
import time

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.jagranjosh.com/')

# %%
gk = driver.find_element(By.XPATH,'/html/body/div/div/div/div[1]/div/div[3]/div/div[1]/header/div[3]/ul/li[9]/a')
gk.click()

# %%
pm = driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div[2]/div/div[10]/div/div/ul/li[2]/a')
pm.click()

# %%
name=[]
Born_dead=[]
Term_of_office=[]
Remark=[]

for i in driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 80px;"]'):
    name.append(i.text)

for i in driver.find_elements(By.XPATH,'//TD[@style="width: 105px; height: 80px;"]'):
    Born_dead.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 80px;"]'):
    Term_of_office.append(i.text)

for i in driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 80px;"]'):
    Remark.append(i.text)

# %%
Priminister1 = pd.DataFrame({'Name': name, 'Born And Dead':Born_dead , 'Term of office' : Term_of_office, 'Remark':Remark})
Priminister1
# Out:
#                           Name Born And Dead  \
# 0    Gulzarilal Nanda (Acting)   (1898-1998)
# 1  Gulzari Lal Nanda  (Acting)   (1898-1998)
# 2                Indira Gandhi   (1917–1984)
# 3                 Charan Singh   (1902–1987)
# 4                 Rajiv Gandhi   (1944–1991)
# 5          P. V. Narasimha Rao   (1921–2004)
# 6         Atal Bihari Vajpayee  (1924- 2018)
# 7             H. D. Deve Gowda   (born 1933)
# 8           Inder Kumar Gujral   (1919–2012)
# 9               Manmohan Singh   (born 1932)
#
#                                       Term of office  \
# 0               27 May 1964 to 9 June 1964,\n13 days
# 1        11 January 1966 to 24 January 1966\n13 days
# 2  24 January 1966 to 24 March 1977\n11 years, 59...
# 3          28 July 1979 to 14 January 1980\n170 days
# 4  31 October 1984 to 2 December 1989\n5 years, 3...
# 5     21 June 1991 to 16 May 1996\n4 years, 330 days
# 6                16 May 1996 to 1 June 1996\n16 days
# ...

# %%
name1=[]
Born_dead1=[]
Term_of_office1=[]
Remark1=[]

for i in driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 121px;"]'):
    name1.append(i.text)

for i in driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 121px;"]'):
    Born_dead1.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 121px;"]'):
    Term_of_office1.append(i.text)

for i in driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 121px;"]'):
    Remark1.append(i.text)

# %%
Priminister2 = pd.DataFrame({'Name': name1, 'Born And Dead':Born_dead1 , 'Term of office' : Term_of_office1, 'Remark':Remark1})
Priminister2
# Out:
#                   Name Born And Dead  \
# 0    Jawahar Lal Nehru   (1889–1964)
# 1  Lal Bahadur Shastri   (1904–1966)
#
#                                       Term of office  \
# 0  15 August 1947 to 27 May 1964\n16 years, 286 days
# 1   9 June 1964 to 11 January 1966\n1 year, 216 days
#
#                                               Remark
# 0  The first prime minister of India and the long...
# 1  He has given the slogan of 'Jai Jawan Jai Kisa...

# %%
name2=[]
Born_dead2=[]
Term_of_office2=[]
Remark2=[]

for i in driver.find_elements(By.XPATH,'//td[@style="width: 150px; height: 104px;"]'):
    name2.append(i.text)

for i in driver.find_elements(By.XPATH,'//td[@style="width: 105px; height: 104px;"]'):
    Born_dead2.append(i.text)
    
for i in driver.find_elements(By.XPATH,'//td[@style="width: 256px; height: 104px;"]'):
    Term_of_office2.append(i.text)

for i in driver.find_elements(By.XPATH,'//td[@style="width: 145px; height: 104px;"]'):
    Remark2.append(i.text)

# %%
Priminister3 = pd.DataFrame({'Name': name2, 'Born And Dead':Born_dead2 , 'Term of office' : Term_of_office2, 'Remark':Remark2})
Priminister3
# Out:
#                    Name Born And Dead  \
# 0         Morarji Desai   (1896–1995)
# 1  Atal Bihari Vajpayee   (1924-2018)
# 2         Narendra Modi   (born 1950)
#
#                                       Term of office  \
# 0  24 March 1977 to  28 July 1979 \n2 year, 126 days
# 1    19 March 1998 to 22 May 2004 \n6 years, 64 days
# 2                              26 May 2014 - Present
#
#                                               Remark
# 0  Oldest to become PM (81 years old) and first t...
# 1   The first non-congress PM who completed a ful...
# 2  4th Prime Minister of India who served two con...

# %%
Pri = pd.DataFrame({'Name': name+name1+name2, 'Born And Dead':Born_dead+Born_dead1+Born_dead2 , 'Term of office' : Term_of_office+Term_of_office1+Term_of_office2, 'Remark':Remark+Remark1+Remark2})
Pri
# Out:
#                            Name Born And Dead  \
# 0     Gulzarilal Nanda (Acting)   (1898-1998)
# 1   Gulzari Lal Nanda  (Acting)   (1898-1998)
# 2                 Indira Gandhi   (1917–1984)
# 3                  Charan Singh   (1902–1987)
# 4                  Rajiv Gandhi   (1944–1991)
# 5           P. V. Narasimha Rao   (1921–2004)
# 6          Atal Bihari Vajpayee  (1924- 2018)
# 7              H. D. Deve Gowda   (born 1933)
# 8            Inder Kumar Gujral   (1919–2012)
# 9                Manmohan Singh   (born 1932)
# 10            Jawahar Lal Nehru   (1889–1964)
# 11          Lal Bahadur Shastri   (1904–1966)
# 12                Morarji Desai   (1896–1995)
# 13         Atal Bihari Vajpayee   (1924-2018)
# 14                Narendra Modi   (born 1950)
# 15                Morarji Desai   (1896–1995)
# 16         Atal Bihari Vajpayee   (1924-2018)
# 17                Narendra Modi   (born 1950)
#
#                                        Term of office  \
# ...

# %% [markdown]
# Q10: Write a python program to display list of 50 Most expensive cars in the world (i.e.
# Car name ,Description and Price) from https://www.motor1.com/
# This task will be done in following steps:
# 1. First get the webpage https://www.motor1.com/
# 2. Then You have to click on the List option from Dropdown menu on leftside.
# 3. Then click on 50 most expensive carsin the world..
# 4. Then scrap the mentioned data and make the

# %%
driver=webdriver.Chrome(r"C:\Users\Shital\chromedriver.exe")

# %%
driver.get('https://www.motor1.com/')

# %%
features = driver.find_element(By.XPATH,'/html/body/div[3]/div[2]/div/div/div[3]/ul/li[3]/a')
features.click()

# %%
mostexp = driver.find_element(By.XPATH,'/html/body/div[3]/div[7]/div/div[1]/div[1]/div[2]/div/div[1]/h3/a')
mostexp.click()

# %%
name=[]

for i in driver.find_elements(By.XPATH,'//h3[@class="subheader"]'):
    name.append(i.text)

TOP50 = pd.DataFrame({'Name of Car': name})
TOP50
# Out:
#                          Name of Car
# 0                          Drako GTE
# 1                      De Tomaso P72
# 2                  Ferrari LaFerrari
# 3                      Pagani Huayra
# 4                       McLaren Elva
# 5                        Czinger 21C
# 6                      Ferrari Monza
# 7                 Gordon Murray T.33
# 8                  Koenigsegg Gemera
# 9                        Zenvo TSR-S
# 10                Hennessey Venom F5
# 11                   Bentley Bacalar
# 12     Hispano Suiza Carmen Boulogne
# 13            Bentley Mulliner Batur
# 14                      Deus Vayanne
# 15                       SSC Tuatara
# 16                       Lotus Evija
# 17               Aston Martin Vulcan
# 18                        Delage D12
# 19                 McLaren Speedtail
# 20                      Rimac Nevera
# 21                     Pagani Utopia
# 22              Pininfarina Battista
# 23                 Ferrari FXX K Evo
# ...
