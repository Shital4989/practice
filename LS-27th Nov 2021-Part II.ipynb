# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\nisar'

# %%
import pandas as pd

# %%
data2=pd.read_csv(r"Mydat3.tsv",sep='\t')

# %%
data2
# Out:
#    Rollno   name  batch
# 0    1001  pinky   1840
# 1    1002   john   1765
# 2    1003   neha   1345
# 3    1004    raj   1540

# %%
data2=pd.read_csv(r"Mydat3.tsv")

# %%
data2
# Out:
#   Rollno\tname\tbatch
# 0   1001\tpinky\t1840
# 1    1002\tjohn\t1765
# 2    1003\tneha\t1345
# 3     1004\traj\t1540

# %% [markdown]
# # If we not used sep agrument it will be llok like above
